# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

dt = 0.01
#t = np.arange(0, 10000000.0, dt)
t = np.logspace(0, 10)
#t
ax.set_title("Query slow down per documents in collection")
ax.set_ylabel('Number of esc finds')
ax.set_xlabel('Documents in Collection')

# AnchorBinaryHop:
# 1 null document
# 1 high point search
# 1 Binary Search
# BinaryHop:
# 1 high point search, chooses 10000 as high point
# 1 ESC read

ax.semilogx(t, 5 + np.log2(t))
ax.grid()

plt.show()
