# %%
import copy
import pandas
import warnings
import subprocess
from matplotlib import pyplot as plt
import os
import sys

sys.path.insert(0, "../src")
#csv_file = "../datasets/genny2/summary.csv"
csv_file = "/tmp/summary.csv"

# %%
# Make a pivot table for average latency for load and graph it
pd = pandas.read_csv(csv_file)
pd1 = pd.query("Query == 'load' & Experiment == 'es3'")
piv = pd1.pivot(index='ContentionFactor', columns="ThreadCount", values="AverageLatencyMillis")

piv.plot(title="ES2 Load: Average Latency", ylabel="Average Latency")
# Out:
# <AxesSubplot: title={'center': 'ES2 Load: Average Latency'}, xlabel='ContentionFactor', ylabel='Average Latency'>

# %%
# Make a pivot table for operation throughput for query and graph it
pd = pandas.read_csv(csv_file)
pd1 = pd.query("QueryNumber == '1' & Experiment == 'es2'")
pd1
# Out:
#     Unnamed: 0                      Task         TaskName Experiment  \
# 21          21    query_es2_1_1.q1.reads    query_es2_1_1        es2
# 26          26    query_es2_1_4.q1.reads    query_es2_1_4        es2
# 31          31    query_es2_1_8.q1.reads    query_es2_1_8        es2
# 36          36   query_es2_1_16.q1.reads   query_es2_1_16        es2
# 41          41    query_es2_4_1.q1.reads    query_es2_4_1        es2
# 46          46    query_es2_4_4.q1.reads    query_es2_4_4        es2
# 51          51    query_es2_4_8.q1.reads    query_es2_4_8        es2
# 56          56   query_es2_4_16.q1.reads   query_es2_4_16        es2
# 61          61    query_es2_8_1.q1.reads    query_es2_8_1        es2
# 66          66    query_es2_8_4.q1.reads    query_es2_8_4        es2
# 71          71    query_es2_8_8.q1.reads    query_es2_8_8        es2
# 76          76   query_es2_8_16.q1.reads   query_es2_8_16        es2
# 81          81   query_es2_16_1.q1.reads   query_es2_16_1        es2
# 86          86   query_es2_16_4.q1.reads   query_es2_16_4        es2
# 91          91   query_es2_16_8.q1.reads   query_es2_16_8        es2
# 96          96  query_es2_16_16.q1.reads  query_es2_16_16        es2
#
#        Phase               Query QueryNumber  ContentionFactor  ThreadCount  \
# 21  q1.reads  fixed_10: fixed_hf           1                 1            1
# 26  q1.reads  fixed_10: fixed_hf           1                 1            4
# 31  q1.reads  fixed_10: fixed_hf           1                 1            8
# 36  q1.reads  fixed_10: fixed_hf           1                 1           16
# 41  q1.reads  fixed_10: fixed_hf           1                 4            1
# 46  q1.reads  fixed_10: fixed_hf           1                 4            4
# 51  q1.reads  fixed_10: fixed_hf           1                 4            8
# 56  q1.reads  fixed_10: fixed_hf           1                 4           16
# 61  q1.reads  fixed_10: fixed_hf           1                 8            1
# 66  q1.reads  fixed_10: fixed_hf           1                 8            4
# 71  q1.reads  fixed_10: fixed_hf           1                 8            8
# 76  q1.reads  fixed_10: fixed_hf           1                 8           16
# 81  q1.reads  fixed_10: fixed_hf           1                16            1
# 86  q1.reads  fixed_10: fixed_hf           1                16            4
# 91  q1.reads  fixed_10: fixed_hf           1                16            8
# 96  q1.reads  fixed_10: fixed_hf           1                16           16
#
#     AverageLatency  ...  WorkersMin  WorkersMax  LatencyMax  LatencyMin  \
# 21   559870.753000  ...           1           1   1453390.0    540679.0
# 26   582542.832850  ...           4           4   1181162.0    531301.0
# 31   597137.247900  ...           8           8   1912880.0    518889.0
# 36   822039.707969  ...          16          16  26639422.0    551787.0
# 41   554213.682900  ...           1           1    839098.0    524574.0
# 46   592480.666050  ...           4           4   1914081.0    546918.0
# 51   629905.275463  ...           8           8   9792436.0    543559.0
# 56   803040.046050  ...          16          16  18039313.0    552347.0
# 61   564981.503900  ...           1           1    894800.0    549302.0
# 66   567937.696125  ...           4           4    945448.0    527234.0
# 71   630280.974650  ...           8           8   2451683.0    552165.0
# 76   825006.636625  ...          16          16  18460633.0    563229.0
# 81   575854.666800  ...           1           1    877669.0    544731.0
# 86   589063.608350  ...           4           4   1563842.0    538317.0
# 91   682922.317200  ...           8           8   2278120.0    556652.0
# 96   823528.287575  ...          16          16  19974471.0    557310.0
#
#     DurationTotal  ErrorsTotal  OperationsTotal  DocumentsTotal   SizeTotal  \
# 21   5.939000e+09          0.0          10000.0         10000.0   3690000.0
# 26   6.305999e+09          0.0          40000.0         40000.0  14760000.0
# 31   6.437999e+09          0.0          80000.0         80000.0  29520000.0
# 36   9.248999e+09          0.0         160000.0        160000.0  59040000.0
# 41   5.904000e+09          0.0          10000.0         10000.0   3690000.0
# 46   6.382000e+09          0.0          40000.0         40000.0  14760000.0
# 51   6.977999e+09          0.0          80000.0         80000.0  29520000.0
# 56   9.047000e+09          0.0         160000.0        160000.0  59040000.0
# 61   6.014999e+09          0.0          10000.0         10000.0   3690000.0
# 66   6.080999e+09          0.0          40000.0         40000.0  14760000.0
# 71   6.848999e+09          0.0          80000.0         80000.0  29520000.0
# 76   1.007400e+10          0.0         160000.0        160000.0  59040000.0
# 81   6.107000e+09          0.0          10000.0         10000.0   3690000.0
# 86   6.313999e+09          0.0          40000.0         40000.0  14760000.0
# 91   7.764999e+09          0.0          80000.0         80000.0  29520000.0
# 96   9.405000e+09          0.0         160000.0        160000.0  59040000.0
#
#     OverheadTotal
# 21   2.879265e+12
# 26   8.439875e+12
# 31   1.632323e+13
# 36   3.519029e+13
# 41   2.840622e+12
# 46   6.133171e+12
# 51   1.237348e+13
# 56   2.730594e+13
# 61   2.733853e+12
# 66   5.011787e+12
# 71   1.009511e+13
# 76   2.467847e+13
# 81   2.884430e+12
# 86   4.324201e+12
# 91   8.598875e+12
# 96   2.059812e+13
#
# [16 rows x 31 columns]

# %%
# Make a pivot table for operation throughput for query and graph it
pd = pandas.read_csv(csv_file)
pd1 = pd.query("QueryNumber == '1' & Experiment == 'es3'")
piv = pd1.pivot(index='ContentionFactor', columns="ThreadCount", values="OperationThroughput")

piv.plot(title="ES2 Load: Operation Throughput", ylabel="Operation Throughput")
# Out:
# <AxesSubplot: title={'center': 'ES2 Load: Operation Throughput'}, xlabel='ContentionFactor', ylabel='Operation Throughput'>

# %%
# Make a pivot table for average latency for query and graph it
pd = pandas.read_csv(csv_file)
pd1 = pd.query("QueryNumber == '2' & Experiment == 'es3'")
piv = pd1.pivot(index='ContentionFactor', columns="ThreadCount", values="AverageLatencyMillis")
piv.plot(title="ES3 Query 2: Average Latency", ylabel="Average Latency (ms)")
# Out:
# <AxesSubplot: title={'center': 'ES3 Query 2: Average Latency'}, xlabel='ContentionFactor', ylabel='Average Latency (ms)'>

# %%
# Make a pivot table for average latency for query and graph it
pd = pandas.read_csv(csv_file)
pd1 = pd.query("QueryNumber == '2' & Experiment == 'es3'")
piv = pd1.pivot(index='ContentionFactor', columns="ThreadCount", values="OperationThroughput")
piv.plot(title="ES3 Query 2: Operation Throughput", ylabel="Operation Throughput")
